# %%
import numpy as np
import numpy.matlib as npmat
import matplotlib.pyplot as plt

# %%
#X=np.random.multivariate_normal([-1,1],npmat.identity(2),100)
N = 1000
X = np.zeros((N,2))
Y = 2*np.random.binomial(1,0.5,N)-1
C = np.array([[2,0],[0,3]])
for i in range(N):
    X[i,:] = np.random.multivariate_normal(Y[i]*np.array([1,1]),[[2,2],[2,3]],1)

# %%
#c = ['red','blue']
plt.scatter(X[:,0],X[:,1], c=Y)
#C = np.array([[2,10],[10,2]])
#plt.figure()
#Z= X.dot(C)
#plt.scatter(Z[:,0],Z[:,1], c=Y)

# %%
np.__version__
# Out:
# '1.16.2'

# %%
import pandas
pandas.__version__
# Out:
# '0.24.2'

# %%
import sys
sys.executable
# Out:
# '/Users/nhitruong/anaconda3/bin/python'
